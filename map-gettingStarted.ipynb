# %% [markdown]
# http://introtopython.org/visualization_earthquakes.html

# %%
# This just lets the output of the following code samples
#  display inline on this page, at an appropriate size.
from pylab import rcParams

# %matplotlib inline
rcParams['figure.figsize'] = (8,6)

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
# make sure the value of resolution is a lowercase L,
#  for 'low', not a numeral 1
my_map = Basemap(projection='ortho', lat_0=50, lon_0=-100,
              resolution='l', area_thresh=1000.0)
 
my_map.drawcoastlines()
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-cb406dedff83> in <module>()
#       8               resolution='l', area_thresh=1000.0)
#       9
# ---> 10 my_map.drawcoastlines()
#      11
#      12 plt.show()
#
# ~/miniconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in drawcoastlines(self, linewidth, linestyle, color, antialiased, ax, zorder)
#    1859         ax.add_collection(coastlines)
#    1860         # set axes limits to fit map region.
# -> 1861         self.set_axes_limits(ax=ax)
#    1862         return coastlines
#    1863
#
# ~/miniconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in set_axes_limits(self, ax)
#    3178                 limb1 = self.drawmapboundary(fill_color='none')
#    3179                 # draw another filled patch, with no boundary.
# -> 3180                 limb2 = self.drawmapboundary(linewidth=0)
#    3181                 self._mapboundarydrawn = limb2
#    3182         # for elliptical map, always turn off axis_frame.
#
# ~/miniconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in drawmapboundary(self, color, linewidth, fill_color, zorder, ax)
#    1621         # if fill_color is string 'none', really don't fill.
#    1622         if fill_color is None:
# -> 1623             fill_color = ax.get_axis_bgcolor()
#    1624         elif fill_color == 'none' or fill_color == 'None':
#    1625             fill_color = None
#
# AttributeError: 'AxesSubplot' object has no attribute 'get_axis_bgcolor'

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
# make sure the value of resolution is a lowercase L,
#  for 'low', not a numeral 1
my_map = Basemap(projection='ortho', lat_0=50, lon_0=-100,
              resolution='l', area_thresh=1000.0)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-ccf3e84d1734> in <module>()
#       8               resolution='l', area_thresh=1000.0)
#       9
# ---> 10 my_map.drawcoastlines()
#      11 my_map.drawcountries()
#      12 my_map.fillcontinents(color='coral')
#
# ~/miniconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in drawcoastlines(self, linewidth, linestyle, color, antialiased, ax, zorder)
#    1859         ax.add_collection(coastlines)
#    1860         # set axes limits to fit map region.
# -> 1861         self.set_axes_limits(ax=ax)
#    1862         return coastlines
#    1863
#
# ~/miniconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in set_axes_limits(self, ax)
#    3178                 limb1 = self.drawmapboundary(fill_color='none')
#    3179                 # draw another filled patch, with no boundary.
# -> 3180                 limb2 = self.drawmapboundary(linewidth=0)
#    3181                 self._mapboundarydrawn = limb2
#    3182         # for elliptical map, always turn off axis_frame.
#
# ~/miniconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py in drawmapboundary(self, color, linewidth, fill_color, zorder, ax)
#    1621         # if fill_color is string 'none', really don't fill.
#    1622         if fill_color is None:
# -> 1623             fill_color = ax.get_axis_bgcolor()
#    1624         elif fill_color == 'none' or fill_color == 'None':
#    1625             fill_color = None
#
# AttributeError: 'AxesSubplot' object has no attribute 'get_axis_bgcolor'
